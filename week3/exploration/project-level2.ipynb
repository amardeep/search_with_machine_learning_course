# %%
import pexpect
import pandas as pd
import subprocess
import string
import nltk
from nltk.stem.snowball import SnowballStemmer

# %%
# %cd /workspace/datasets/fasttext
# Out:
# /home/jupyter/.kaggle/datasets/fasttext

# %% [markdown]
# ## Extract titles

# %% [markdown]
# Following code for transformation is used:

# %%
translation_table = str.maketrans("", "", "®©™" + string.punctuation)

def transform_training_data(name):
    name = name.replace("\n", " ")
    name = name.lower()
    # remove punctuation
    name = name.translate(translation_table)
    tokens = nltk.word_tokenize(name)
    stemmer = SnowballStemmer("english")
    tokens = [stemmer.stem(t) for t in tokens]
    return " ".join(tokens)

# %%
# %%bash
# set -x
# python /workspace/search_with_machine_learning_course/week3/extractTitles.py --sample_rate 1.0
# wc -l /workspace/datasets/fasttext/titles.txt
# Out:
# + python /workspace/search_with_machine_learning_course/week3/extractTitles.py --sample_rate 1.0
# Writing results to /workspace/datasets/fasttext/titles.txt
# + wc -l /workspace/datasets/fasttext/titles.txt
# 115358 /workspace/datasets/fasttext/titles.txt

# %% [markdown]
# ## Words used for evaluation

# %%
words = [
    "Printer", "Vaccum", "Headphones", "Binoculars", "Phones", 
    "Apple", "AMD", "Bosch", "Canon", "Skullcandy",
    "FinePix", "Macbook", "Wii", "Aspire", "Ipad",
    "16GB", "Black", "Bonus", "Wireless", "USB", 
]

# %% [markdown]
# ## Evaluation

# %%
def run_exp(minCount = 0):
    # Train model
    dir = "/workspace/datasets/fasttext/"
    model = f"title_model.mc{minCount}"
    cmd = f"fasttext skipgram -input titles.txt -output {model} -minCount {minCount}"
    print(f"+ {cmd}")
    subprocess.run(cmd, shell=True, cwd=dir)

    # Eval on words
    rows = []
    cmd = f"fasttext nn {model}.bin"
    print(f"+ {cmd}")
    child=pexpect.spawn(cmd, encoding='utf-8')
    child.expect('Query word?')
    for input_word in words:
        word = transform_training_data(input_word)
        child.sendline(word)
        child.expect('Query word?')
        output = child.before
        lines = output.strip().split("\r\n")[1:]
        splits = [line.strip().split() for line in lines]
        row = [f"{input_word} ({word})"] + [f"{o[0]}: {float(o[1]):.3f}" for o in splits]
        rows.append(row)
    child.close()
    df = pd.DataFrame(rows)
    display(df)

# %% [markdown]
# ### minCount = 0

# %%
run_exp(minCount=0)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc0 -minCount 0
# Read 1M words
# Number of words:  28416
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   49374 lr:  0.000000 avg.loss:  1.555754 ETA:   0h 0m 0s
# + fasttext nn title_model.mc0.bin
#                          0                        1                     2   \
# 0         Printer (printer)          sprinter: 0.897         printz: 0.887
# 1           Vaccum (vaccum)  vacuumblowerinfl: 0.910            cv2: 0.890
# 2     Headphones (headphon)         headphoni: 0.967  headphonesear: 0.941
# 3    Binoculars (binocular)         monocular: 0.909        ab10462: 0.864
# 4            Phones (phone)            vphone: 0.958         phonem: 0.952
# 5              Apple (appl)            apple­: 0.928         appleâ: 0.921
# 6                 AMD (amd)         athlonâ¢: 0.924         athlon: 0.913
# 7             Bosch (bosch)           ascenta: 0.843           axxi: 0.842
# 8             Canon (canon)            icanon: 0.945         cannon: 0.872
# 9   Skullcandy (skullcandi)            skullz: 0.954          skull: 0.933
# 10        FinePix (finepix)          fujifilm: 0.963        fujifil: 0.945
# 11        Macbook (macbook)             ibook: 0.851      toughbook: 0.841
# 12                Wii (wii)              wiib: 0.900       nintendo: 0.894
# 13           Aspire (aspir)        aspirerevo: 0.918     ao722c62bb: 0.870
# 14              Ipad (ipad)             ipad­: 0.959          ipad°: 0.955
# 15              16GB (16gb)             w32gb: 0.897           32gb: 0.894
# 16            Black (black)         blackpewt: 0.900      blackpepp: 0.894
# 17            Bonus (bonus)          pikachus: 0.837           poni: 0.835
# 18      Wireless (wireless)     wiredwireless: 0.976      wirelessb: 0.946
# 19                USB (usb)              wusb: 0.947           usb2: 0.929
#
#                            3                          4   \
# 0   printerphotocaptur: 0.886  printercopierscann: 0.873
# 1                  vac: 0.888                 fjm: 0.883
# 2               earbud: 0.909          overtheear: 0.890
# 3              ab10762: 0.863             ab10526: 0.863
# 4             phonemp3: 0.891         phoneunlock: 0.883
# 5                ipadâ: 0.893               ipad­: 0.891
# 6                 rm72: 0.911           phenomâ¢: 0.909
# 7        steamdishwash: 0.819               boseâ: 0.807
# 8                   eo: 0.819               hanon: 0.818
# 9               skulli: 0.924          skullcrush: 0.924
# 10             coolpix: 0.897             f770exr: 0.895
# 11              ezbook: 0.840               bbook: 0.832
# 12           nintendog: 0.881                wwii: 0.849
# 13   as5349b814g32mnkk: 0.864   as7250e454g50mnkk: 0.858
# 14               ipadâ: 0.944             ipadâ¢: 0.943
# 15                96gb: 0.885                 8gb: 0.884
# 16             60black: 0.892      blackgoldblack: 0.892
# 17         012duodecim: 0.825           tinkerbel: 0.822
# 18          wirelesshd: 0.942          wirelessag: 0.937
# 19            usbtousb: 0.895               m1usb: 0.894
#
#                                 5                          6   \
# 0   printercopierscannerfax: 0.867           printcalc: 0.860
# 1                        cv: 0.873             liftoff: 0.872
# 2             multiheadphon: 0.879              yurbud: 0.878
# 3                   ab10592: 0.862             ab10572: 0.861
# 4                     phono: 0.860   phonefaxmodemansw: 0.847
# 5                     ipad°: 0.888             ipadâ¢: 0.886
# 6                      zm82: 0.906                tk53: 0.898
# 7                   talltub: 0.803            dishwash: 0.800
# 8                       50d: 0.807                 30d: 0.807
# 9                    earbud: 0.873                 sku: 0.862
# 10                    160mp: 0.894               140mp: 0.894
# 11                 omnibook: 0.827             zenbook: 0.822
# 12                    wiigo: 0.813                  ds: 0.803
# 13        as57502634g64mnkk: 0.857  as5749zb964g50mnkk: 0.857
# 14                   ipadst: 0.892                appl: 0.842
# 15                   4gb8gb: 0.871                64gb: 0.860
# 16                    blacx: 0.890            blackmet: 0.888
# 17                     tini: 0.820            duodecim: 0.820
# 18               wirelessac: 0.937        miniwireless: 0.928
# 19                    usbdc: 0.881              800usb: 0.845
#
#                                            7                         8   \
# 0   printercopierscannerfaxphotocaptur: 0.850          mfc7860dw: 0.838
# 1                               vacuum: 0.872          rotosweep: 0.870
# 2                         behindtheear: 0.860        undertheear: 0.843
# 3                              ab10962: 0.860            ab10768: 0.854
# 4                                   i9: 0.845           cellphon: 0.839
# 5                                 ipgx: 0.864                ip4: 0.863
# 6                               phenom: 0.897            quadcor: 0.896
# 7                                 2378: 0.786          glmb209dq: 0.783
# 8                                  60d: 0.806             eos40d: 0.803
# 9                               yurbud: 0.857             budbud: 0.833
# 10                             f660exr: 0.889            hs20exr: 0.887
# 11                            casebook: 0.821           durabook: 0.803
# 12                             gamecub: 0.787              wiggl: 0.777
# 13                   as57502456g50mtkk: 0.854  as57492354g50mnkk: 0.854
# 14                          csipad2whi: 0.831           padfolio: 0.823
# 15                               754gb: 0.840         dt10816gbz: 0.840
# 16                             blackic: 0.885             blaclr: 0.877
# 17                                  az: 0.819             voodoo: 0.818
# 18                        wireless150n: 0.922       wireless300n: 0.922
# 19                           satatousb: 0.828            14tousb: 0.827
#
#                            9                       10
# 0            mfc9010cn: 0.837        mfc8480dn: 0.836
# 1                  vax: 0.870               5l: 0.866
# 2      earbudmicrophon: 0.843      overthehead: 0.843
# 3              ab10286: 0.853          ab10594: 0.845
# 4               phonic: 0.823          kyocera: 0.820
# 5                ipodâ: 0.857       appleiphon: 0.854
# 6                 wamd: 0.895         iiphenom: 0.893
# 7             aquastop: 0.783  builtindishwash: 0.779
# 8              fujinon: 0.800             cann: 0.798
# 9                 inkd: 0.832              bud: 0.813
# 10             hs30exr: 0.887          hs25exr: 0.886
# 11                  g4: 0.800         codebook: 0.797
# 12                 3ds: 0.772         gameclub: 0.770
# 13  as556083524g50mnkk: 0.854     aod257n57dkk: 0.853
# 14            podfolio: 0.813              3rd: 0.810
# 15                fxgb: 0.838              7gb: 0.837
# 16             blackol: 0.874         blackhot: 0.870
# 17               alibi: 0.818             boyl: 0.817
# 18        wirelessmimo: 0.916     mywirelesstv: 0.901
# 19               cdusb: 0.826            usb20: 0.825

# %% [markdown]
# ### minCount = 10

# %%
run_exp(minCount=10)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc10 -minCount 10
# Read 1M words
# Number of words:  6021
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   55256 lr:  0.000000 avg.loss:  1.421799 ETA:   0h 0m 0s
# + fasttext nn title_model.mc10.bin
#                          0                          1   \
# 0         Printer (printer)  printercopierscann: 0.850
# 1           Vaccum (vaccum)              vacuum: 0.856
# 2     Headphones (headphon)              earbud: 0.872
# 3    Binoculars (binocular)               scope: 0.776
# 4            Phones (phone)              huawei: 0.801
# 5              Apple (appl)              appleâ: 0.849
# 6                 AMD (amd)              athlon: 0.892
# 7             Bosch (bosch)             ascenta: 0.816
# 8             Canon (canon)                  eo: 0.814
# 9   Skullcandy (skullcandi)               skull: 0.892
# 10        FinePix (finepix)            fujifilm: 0.949
# 11        Macbook (macbook)            bookendz: 0.783
# 12                Wii (wii)            nintendo: 0.869
# 13           Aspire (aspir)                n270: 0.759
# 14              Ipad (ipad)                appl: 0.784
# 15              16GB (16gb)                32gb: 0.874
# 16            Black (black)           blackwhit: 0.765
# 17            Bonus (bonus)               mysim: 0.744
# 18      Wireless (wireless)           wirelessg: 0.859
# 19                USB (usb)           20firewir: 0.705
#
#                                 2                   3                 4   \
# 0   printercopierscannerfax: 0.848       inkjet: 0.800     copier: 0.798
# 1                    roomba: 0.845   windtunnel: 0.841    liftoff: 0.838
# 2                overtheear: 0.869  overthehead: 0.804     yurbud: 0.797
# 3                    barska: 0.768      bushnel: 0.739       2060: 0.704
# 4                   kyocera: 0.778       gophon: 0.777      phono: 0.776
# 5                      ipad: 0.784         ipod: 0.769      iphon: 0.763
# 6                    phenom: 0.883         tl60: 0.860    quadcor: 0.851
# 7                   integra: 0.783         2378: 0.736    woodlik: 0.715
# 8                       60d: 0.786          t2i: 0.773   canoscan: 0.773
# 9                    earbud: 0.835         inkd: 0.831       hesh: 0.784
# 10                      z37: 0.917         xp20: 0.917        z90: 0.906
# 11                      154: 0.762           g4: 0.754  powerbook: 0.737
# 12                nintendog: 0.858           ds: 0.828       wwii: 0.769
# 13                      116: 0.739      ideapad: 0.718       acer: 0.717
# 14                      3rd: 0.770    portfolio: 0.768      folio: 0.752
# 15                      8gb: 0.838         64gb: 0.802        4gb: 0.720
# 16               blackpurpl: 0.764     blacktop: 0.763     blackr: 0.756
# 17                    zombi: 0.740        vacat: 0.732        zhu: 0.730
# 18                wirelessn: 0.770       80211b: 0.649     80211g: 0.646
# 19                  drivest: 0.701           20: 0.680       3020: 0.680
#
#                    5                   6                     7   \
# 0    officejet: 0.790      deskjet: 0.787    dx4860ub32p: 0.779
# 1      vacmast: 0.834       canist: 0.831            vac: 0.828
# 2      earphon: 0.785    noiseisol: 0.778  behindtheneck: 0.765
# 3    celestron: 0.687     circular: 0.678         pentax: 0.660
# 4       tmobil: 0.770         razr: 0.748             4g: 0.743
# 5       ipodhd: 0.755     3rdgener: 0.732       4thgener: 0.721
# 6          3gb: 0.845          am3: 0.839             x6: 0.829
# 7           67: 0.713      tassimo: 0.711       dishwash: 0.709
# 8          50d: 0.770        pixma: 0.767             7d: 0.767
# 9       yurbud: 0.780         gumi: 0.776            bud: 0.774
# 10     coolpix: 0.865         w570: 0.855           s210: 0.853
# 11    facebook: 0.684   brenthaven: 0.678        macbeth: 0.675
# 12     gamecub: 0.767          360: 0.721            3ds: 0.717
# 13    i72670qm: 0.717     obsidian: 0.716        sapphir: 0.708
# 14     tribeca: 0.720  ipadnetbook: 0.719          bodhi: 0.717
# 15      memori: 0.715          6gb: 0.713       jumpdriv: 0.695
# 16  blackorang: 0.754    blacksilv: 0.741      blackgold: 0.737
# 17        poni: 0.720     littlest: 0.715        paradis: 0.715
# 18     keyless: 0.639         m305: 0.631           m325: 0.627
# 19       drive: 0.669     jumpdriv: 0.667        firewir: 0.654
#
#                    8                     9                  10
# 0      hl2170w: 0.776            fax: 0.775       pixma: 0.769
# 1          vax: 0.825        bagless: 0.815      eureka: 0.811
# 2   skullcandi: 0.764  behindthehead: 0.752         bud: 0.735
# 3   altazimuth: 0.609          146mp: 0.606     popular: 0.604
# 4        mobil: 0.742        pantech: 0.741         att: 0.740
# 5     6thgener: 0.720          3g3gs: 0.714    5thgener: 0.714
# 6       turion: 0.826             x4: 0.823          x2: 0.802
# 7         50lb: 0.694        accubak: 0.692     talltub: 0.686
# 8      sx230hs: 0.756          151mp: 0.752         xsi: 0.750
# 9       smokin: 0.767       headphon: 0.764         2xl: 0.759
# 10        w310: 0.852          pl210: 0.848        w370: 0.848
# 11    lifebook: 0.671      ultrabook: 0.668    hardshel: 0.662
# 12    challeng: 0.708        paradis: 0.702    usaopoli: 0.699
# 13      qosmio: 0.700        pentium: 0.696    biscotti: 0.695
# 14      appleâ: 0.702       ipodipad: 0.692     generat: 0.690
# 15        12gb: 0.693            2gb: 0.684       256gb: 0.677
# 16  whiteblack: 0.732       redblack: 0.727   blackpink: 0.726
# 17    usaopoli: 0.707          resid: 0.707  borderland: 0.706
# 18      80211n: 0.615         router: 0.595     hl2170w: 0.581
# 19     20esata: 0.653         goflex: 0.648     attaché: 0.623

# %% [markdown]
# ### minCount = 20

# %%
run_exp(minCount=20)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc20 -minCount 20
# Read 1M words
# Number of words:  3901
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   59115 lr:  0.000000 avg.loss:  1.426001 ETA:   0h 0m 0s
# + fasttext nn title_model.mc20.bin
#                          0                          1                  2   \
# 0         Printer (printer)  printercopierscann: 0.840   officejet: 0.815
# 1           Vaccum (vaccum)              vacuum: 0.805  windtunnel: 0.790
# 2     Headphones (headphon)              earbud: 0.894  overtheear: 0.855
# 3    Binoculars (binocular)              barska: 0.790       scope: 0.787
# 4            Phones (phone)             kyocera: 0.788          4g: 0.751
# 5              Apple (appl)              appleâ: 0.842       iphon: 0.752
# 6                 AMD (amd)              athlon: 0.899        tl60: 0.853
# 7             Bosch (bosch)             ascenta: 0.820     integra: 0.737
# 8             Canon (canon)                  eo: 0.789         t2i: 0.778
# 9   Skullcandy (skullcandi)                inkd: 0.819        hesh: 0.806
# 10        FinePix (finepix)            fujifilm: 0.931        m893: 0.847
# 11        Macbook (macbook)                 154: 0.777          g4: 0.744
# 12                Wii (wii)            nintendo: 0.875          ds: 0.818
# 13           Aspire (aspir)                 116: 0.735        acer: 0.734
# 14              Ipad (ipad)                 3rd: 0.754        appl: 0.718
# 15              16GB (16gb)                32gb: 0.840         8gb: 0.811
# 16            Black (black)              blackr: 0.760   blackwhit: 0.756
# 17            Bonus (bonus)                payn: 0.726       mysim: 0.704
# 18      Wireless (wireless)           wirelessg: 0.859   wirelessn: 0.795
# 19                USB (usb)            jumpdriv: 0.652        3020: 0.646
#
#                    3                 4                   5   \
# 0      deskjet: 0.800     inkjet: 0.797       s51204: 0.778
# 1          vac: 0.788    foodsav: 0.781       canist: 0.779
# 2    noiseisol: 0.800    earphon: 0.797          bud: 0.776
# 3      bushnel: 0.753   circular: 0.704    celestron: 0.695
# 4       gophon: 0.750    pantech: 0.744         8520: 0.743
# 5         ipod: 0.728       ipad: 0.718    ipodiphon: 0.678
# 6       phenom: 0.842     turion: 0.841      quadcor: 0.829
# 7           67: 0.709    tassimo: 0.707         2378: 0.705
# 8          xsi: 0.773        60d: 0.766           t3: 0.764
# 9       earbud: 0.804     smokin: 0.793       lowrid: 0.772
# 10     coolpix: 0.846       m863: 0.833         m340: 0.828
# 11   powerbook: 0.698  ultrabook: 0.654        moshi: 0.642
# 12        wwii: 0.794   challeng: 0.772      gamecub: 0.743
# 13        n270: 0.720    ideapad: 0.687      sapphir: 0.681
# 14       folio: 0.714  portfolio: 0.704  ipadnetbook: 0.692
# 15        64gb: 0.751       12gb: 0.701          6gb: 0.699
# 16  blackorang: 0.719  blackpink: 0.717  blackyellow: 0.710
# 17      museum: 0.695         mr: 0.691     dinosaur: 0.685
# 18      80211b: 0.589     80211g: 0.581        24ghz: 0.577
# 19          20: 0.633     iomega: 0.621      firewir: 0.615
#
#                    6                     7                   8   \
# 0     eallinon: 0.778         copier: 0.777        pixma: 0.767
# 1      bagless: 0.778        filtret: 0.777       eureka: 0.762
# 2   skullcandi: 0.769  behindtheneck: 0.765  noisecancel: 0.756
# 3       pentax: 0.650           mead: 0.642    refractor: 0.607
# 4          att: 0.737           razr: 0.732         8530: 0.732
# 5    radioappl: 0.657          3g3gs: 0.654     4thgener: 0.637
# 6          3gb: 0.829        sempron: 0.825           x2: 0.812
# 7     dishwash: 0.695        accubak: 0.693       maytag: 0.675
# 8           7d: 0.763          pixma: 0.762          t1i: 0.758
# 9     headphon: 0.769            bud: 0.766          2xl: 0.758
# 10        s210: 0.820          m1063: 0.815        140mp: 0.809
# 11       ebook: 0.641            133: 0.638      macbeth: 0.635
# 12      resort: 0.712            3ds: 0.703       rabbid: 0.700
# 13    inspiron: 0.679       biscotti: 0.677     obsidian: 0.671
# 14       iphon: 0.687          bodhi: 0.679      generat: 0.679
# 15       256gb: 0.674            4gb: 0.672       memori: 0.666
# 16   pinkblack: 0.703       redblack: 0.700    blacksilv: 0.693
# 17      beyond: 0.684          zelda: 0.684      paradis: 0.679
# 18        wire: 0.560         router: 0.549      deskjet: 0.522
# 19  datatravel: 0.612        atomini: 0.603      attaché: 0.599
#
#                    9                        10
# 0     laserjet: 0.767           scanjet: 0.766
# 1       roomba: 0.758            irobot: 0.725
# 2         hesh: 0.755              inkd: 0.725
# 3         spot: 0.603        waterproof: 0.600
# 4     ericsson: 0.731        nocontract: 0.730
# 5           4s: 0.634               3gs: 0.632
# 6           x4: 0.804          biscotti: 0.791
# 7       15cycl: 0.674  blackonstainless: 0.673
# 8          t3i: 0.752             sx150: 0.748
# 9    noiseisol: 0.744              gumi: 0.715
# 10      sd1400: 0.807          sd1300is: 0.804
# 11    lifebook: 0.629            cocoon: 0.618
# 12    showdown: 0.698             mysim: 0.690
# 13     spinner: 0.669           emachin: 0.666
# 14       easel: 0.651            appleâ: 0.646
# 15    jumpdriv: 0.666                gb: 0.645
# 16  whiteblack: 0.692         blueblack: 0.677
# 17      beauti: 0.679        borderland: 0.676
# 18     5button: 0.516           gamepad: 0.509
# 19   datastick: 0.591            minist: 0.591

# %% [markdown]
# ### minCount = 50

# %%
run_exp(minCount=50)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc50 -minCount 50
# Read 1M words
# Number of words:  2152
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   69814 lr:  0.000000 avg.loss:  1.483654 ETA:   0h 0m 0s
# + fasttext nn title_model.mc50.bin
#                          0                 1                   2   \
# 0         Printer (printer)  officejet: 0.813        pixma: 0.794
# 1           Vaccum (vaccum)     vacuum: 0.864          vac: 0.852
# 2     Headphones (headphon)     earbud: 0.852   overtheear: 0.817
# 3    Binoculars (binocular)      scope: 0.783      bushnel: 0.770
# 4            Phones (phone)        att: 0.748      kyocera: 0.740
# 5              Apple (appl)      iphon: 0.752         ipad: 0.728
# 6                 AMD (amd)     athlon: 0.894       turion: 0.850
# 7             Bosch (bosch)         67: 0.679       maytag: 0.660
# 8             Canon (canon)         eo: 0.751          t1i: 0.749
# 9   Skullcandy (skullcandi)        bud: 0.761       earbud: 0.758
# 10        FinePix (finepix)   fujifilm: 0.933       exilim: 0.812
# 11        Macbook (macbook)        133: 0.619        moshi: 0.613
# 12                Wii (wii)   nintendo: 0.823           ds: 0.798
# 13           Aspire (aspir)       acer: 0.725          116: 0.720
# 14              Ipad (ipad)  portfolio: 0.775          3rd: 0.765
# 15              16GB (16gb)       32gb: 0.811          8gb: 0.802
# 16            Black (black)  blackwhit: 0.703       blackr: 0.683
# 17            Bonus (bonus)      sanus: 0.717  martinlogan: 0.695
# 18      Wireless (wireless)  wirelessg: 0.843    wirelessn: 0.756
# 19                USB (usb)         20: 0.635       iomega: 0.610
#
#                     3                 4                  5   \
# 0        inkjet: 0.784   laserjet: 0.776      copier: 0.768
# 1       bagless: 0.828     canist: 0.792      eureka: 0.762
# 2   noisecancel: 0.749        bud: 0.722  skullcandi: 0.700
# 3        barska: 0.768  celestron: 0.742      pentax: 0.677
# 4      motorola: 0.733    handset: 0.730        razr: 0.728
# 5          ipod: 0.699        3gs: 0.636          4s: 0.627
# 6        phenom: 0.830        3gb: 0.826          x2: 0.802
# 7     washerdry: 0.660         ge: 0.656   architect: 0.650
# 8           t2i: 0.745        xsi: 0.742       pixma: 0.739
# 9        ifrogz: 0.718       gumi: 0.715    headphon: 0.700
# 10         fuji: 0.811    coolpix: 0.805       140mp: 0.796
# 11        speck: 0.601    seethru: 0.594       incas: 0.587
# 12     challeng: 0.769    gamecub: 0.740         3ds: 0.726
# 13      ideapad: 0.674   inspiron: 0.674      athlon: 0.668
# 14         appl: 0.728      folio: 0.721       iphon: 0.678
# 15         64gb: 0.728        4gb: 0.670         6gb: 0.660
# 16   whiteblack: 0.664  blacksilv: 0.659   blueblack: 0.637
# 17         bond: 0.693      sonax: 0.664   bookshelf: 0.645
# 18        24ghz: 0.596     80211g: 0.577     gamepad: 0.533
# 19        drive: 0.590    collegi: 0.572     attaché: 0.566
#
#                      6                  7                     8   \
# 0   networkreadi: 0.745         fax: 0.719          toner: 0.715
# 1        filtret: 0.745      wetdri: 0.742         hoover: 0.741
# 2      microphon: 0.684       inear: 0.672            ear: 0.671
# 3           zoom: 0.587  waterproof: 0.578           spot: 0.571
# 4        verizon: 0.727       nokia: 0.726       cellstar: 0.711
# 5       4thgener: 0.625    3rdgener: 0.613        tribeca: 0.595
# 6             x4: 0.795     pentium: 0.787        dualcor: 0.740
# 7         evolut: 0.646  cleansteel: 0.645  bisqueonbisqu: 0.636
# 8             7d: 0.732         t3i: 0.725             t3: 0.720
# 9        armband: 0.657        ipod: 0.621          altec: 0.620
# 10         lumix: 0.774       120mp: 0.759           72mp: 0.756
# 11            13: 0.587        nook: 0.580             i7: 0.565
# 12           360: 0.704         psp: 0.699           xbox: 0.692
# 13       emachin: 0.658     pentium: 0.654            156: 0.638
# 14          slip: 0.673     generat: 0.653        tribeca: 0.628
# 15           2gb: 0.653          ep: 0.625             gb: 0.624
# 16      redblack: 0.634   blackgray: 0.630       blackblu: 0.610
# 17  polypropylen: 0.644  floorstand: 0.634         inceil: 0.633
# 18          wire: 0.532      router: 0.513           mous: 0.485
# 19       firewir: 0.552      goflex: 0.550        skatedr: 0.545
#
#                   9                    10
# 0     lexmark: 0.712  blackandwhit: 0.711
# 1        hepa: 0.729        bissel: 0.715
# 2    sennheis: 0.669        clipon: 0.654
# 3   blackhawk: 0.557      wideangl: 0.537
# 4    ericsson: 0.700     smartphon: 0.696
# 5   portfolio: 0.589         incas: 0.582
# 6          i3: 0.709           msi: 0.708
# 7    dishwash: 0.635     whirlpool: 0.629
# 8       rebel: 0.710          elph: 0.709
# 9      stereo: 0.619           ear: 0.619
# 10       elph: 0.743         optio: 0.738
# 11        116: 0.558          pros: 0.555
# 12   playstat: 0.673         puzzl: 0.667
# 13        msi: 0.630       celeron: 0.626
# 14         4s: 0.623         sleev: 0.621
# 15     memori: 0.604         128gb: 0.586
# 16  grayblack: 0.610         white: 0.605
# 17      bello: 0.626         round: 0.622
# 18   dualband: 0.482          sale: 0.480
# 19      4port: 0.540         flash: 0.532
