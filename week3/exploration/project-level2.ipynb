# %%
import pexpect
import pandas as pd
import subprocess
import string
import nltk
from nltk.stem.snowball import SnowballStemmer

# %%
# %cd /workspace/datasets/fasttext
# Out:
# /home/jupyter/.kaggle/datasets/fasttext

# %% [markdown]
# ## Extract titles

# %% [markdown]
# Following code for transformation is used:

# %%
translation_table = str.maketrans("", "", string.punctuation)

def transform_training_data(name):
    name = name.replace("\n", " ")
    name = name.lower()
    # remove punctuation
    name = name.translate(translation_table)
    tokens = nltk.word_tokenize(name)
    stemmer = SnowballStemmer("english")
    tokens = [stemmer.stem(t) for t in tokens]
    return " ".join(tokens)

# %%
# %%bash
# set -x
# python /workspace/search_with_machine_learning_course/week3/extractTitles.py --sample_rate 1.0
# wc -l /workspace/datasets/fasttext/titles.txt
# Out:
# + python /workspace/search_with_machine_learning_course/week3/extractTitles.py --sample_rate 1.0
# Writing results to /workspace/datasets/fasttext/titles.txt
# + wc -l /workspace/datasets/fasttext/titles.txt
# 115358 /workspace/datasets/fasttext/titles.txt

# %% [markdown]
# ## Words used for evaluation

# %%
words = [
    "Printer", "Vaccum", "Headphones", "Binoculars", "Phones", 
    "Apple", "AMD", "Bosch", "Canon", "Skullcandy",
    "FinePix", "Macbook", "Wii", "Aspire", "Ipad",
    "16GB", "Black", "Bonus", "Wireless", "USB", 
]

# %% [markdown]
# ## Evaluation

# %%
def run_exp(minCount = 0):
    # Train model
    dir = "/workspace/datasets/fasttext/"
    model = f"title_model.mc{minCount}"
    cmd = f"fasttext skipgram -input titles.txt -output {model} -minCount {minCount}"
    print(f"+ {cmd}")
    subprocess.run(cmd, shell=True, cwd=dir)

    # Eval on words
    rows = []
    cmd = f"fasttext nn {model}.bin"
    print(f"+ {cmd}")
    child=pexpect.spawn(cmd, encoding='utf-8')
    child.expect('Query word?')
    for input_word in words:
        word = transform_training_data(input_word)
        child.sendline(word)
        child.expect('Query word?')
        output = child.before
        lines = output.strip().split("\r\n")[1:]
        splits = [line.strip().split() for line in lines]
        row = [f"{input_word} ({word})"] + [f"{o[0]}: {float(o[1]):.3f}" for o in splits]
        rows.append(row)
    child.close()
    df = pd.DataFrame(rows)
    display(df)

# %% [markdown]
# ### minCount = 0

# %%
run_exp(minCount=0)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc0 -minCount 0
# Read 1M words
# Number of words:  28622
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   49836 lr:  0.000000 avg.loss:  1.527039 ETA:   0h 0m 0s words/sec/thread:   49837 lr: -0.000004 avg.loss:  1.527039 ETA:   0h 0m 0s
# + fasttext nn title_model.mc0.bin
#                          0                     1                          2   \
# 0         Printer (printer)       sprinter: 0.903  printerphotocaptur: 0.881
# 1           Vaccum (vaccum)           vac™: 0.925            liftoff®: 0.901
# 2     Headphones (headphon)      headphoni: 0.969       headphonesear: 0.942
# 3    Binoculars (binocular)      monocular: 0.911             ab10592: 0.877
# 4            Phones (phone)         vphone: 0.957              phonem: 0.947
# 5              Apple (appl)         apple­: 0.908             appleâ®: 0.848
# 6                 AMD (amd)        athlon™: 0.929             phenom™: 0.917
# 7             Bosch (bosch)        ascenta: 0.842                axxi: 0.837
# 8             Canon (canon)         icanon: 0.945              cannon: 0.845
# 9   Skullcandy (skullcandi)         skullz: 0.947              skulli: 0.924
# 10        FinePix (finepix)       fujifilm: 0.966             fujifil: 0.952
# 11        Macbook (macbook)       macbook™: 0.980            macbook®: 0.960
# 12                Wii (wii)           wiib: 0.906            nintendo: 0.900
# 13           Aspire (aspir)     aspirerevo: 0.912          ao722c62bb: 0.862
# 14              Ipad (ipad)          ipad°: 0.966               ipad­: 0.964
# 15              16GB (16gb)           32gb: 0.917               w32gb: 0.899
# 16            Black (black)        60black: 0.892           blackpewt: 0.889
# 17            Bonus (bonus)           boyl: 0.848            pikachus: 0.838
# 18      Wireless (wireless)  wiredwireless: 0.976           wirelessb: 0.948
# 19                USB (usb)           wusb: 0.942                usb2: 0.932
#
#                            3                               4   \
# 0   printercopierscann: 0.870  printercopierscannerfax: 0.866
# 1     vacuumblowerinfl: 0.899                      vac: 0.894
# 2               earbud: 0.902               overtheear: 0.888
# 3              ab10572: 0.865                  ab10526: 0.859
# 4             phonemp3: 0.896              phoneunlock: 0.892
# 5           applecreek: 0.846                   apple®: 0.843
# 6            athlonâ¢: 0.915                  turion™: 0.913
# 7        steamdishwash: 0.813                  talltub: 0.797
# 8              fujinon: 0.829                      50d: 0.826
# 9                skull: 0.923               skullcrush: 0.909
# 10             hs30exr: 0.894                    140mp: 0.892
# 11              ibook®: 0.932                 bookendz: 0.836
# 12           nintendog: 0.895                     wwii: 0.858
# 13   as5349b814g32mnkk: 0.858        as7250e454g50mnkk: 0.856
# 14             ipadâ¢: 0.958                    ipad®: 0.951
# 15                 8gb: 0.882                     96gb: 0.879
# 16            blackmet: 0.885           blackgoldblack: 0.885
# 17                bowi: 0.829                    alibi: 0.829
# 18          wirelesshd: 0.944               wirelessag: 0.941
# 19            usbtousb: 0.889                    usbdc: 0.879
#
#                            5                                          6   \
# 0               printz: 0.866  printercopierscannerfaxphotocaptur: 0.849
# 1              liftoff: 0.890                                 cv2: 0.887
# 2      earbudmicrophon: 0.884                       multiheadphon: 0.874
# 3              ab10762: 0.858                             ab10594: 0.857
# 4                phono: 0.857                   phonefaxmodemansw: 0.852
# 5              applesc: 0.843                           applework: 0.811
# 6            phenomâ¢: 0.907                             phenom®: 0.905
# 7                  tub: 0.796                                2378: 0.796
# 8                   eo: 0.810                                 t4i: 0.810
# 9                  sku: 0.860                              earbud: 0.833
# 10             hs20exr: 0.891                                 z37: 0.891
# 11            kabookii: 0.829                            bookbook: 0.826
# 12                  ds: 0.832                               wiigo: 0.831
# 13  as5750zb964g32mnbb: 0.853                  as5750zb964g32mnrr: 0.851
# 14              ipadâ®: 0.940                               ipad™: 0.918
# 15                64gb: 0.875                              4gb8gb: 0.862
# 16           blackpepp: 0.884                               blacx: 0.874
# 17           democraci: 0.825                                bocc: 0.825
# 18          wirelessac: 0.939                        miniwireless: 0.928
# 19               m1usb: 0.875                              800usb: 0.846
#
#                      7                          8                          9   \
# 0      mfc7860dw: 0.845            mfc7440n: 0.840           mfc9010cn: 0.840
# 1     selfpropel: 0.874              febrez: 0.870             foodsav: 0.869
# 2   behindtheear: 0.859              yurbud: 0.857         undertheear: 0.846
# 3        ab10768: 0.852             ab10286: 0.850             ab10962: 0.849
# 4       cellphon: 0.845              phonic: 0.829             kyocera: 0.824
# 5            app: 0.809             applica: 0.801              applic: 0.798
# 6           rm72: 0.903                tk53: 0.902            sempron™: 0.901
# 7       dishwash: 0.790              boseâ®: 0.789                50lb: 0.782
# 8            60d: 0.809                 t1i: 0.803             t2i550d: 0.801
# 9           inkd: 0.823              yurbud: 0.804           headphoni: 0.798
# 10       f770exr: 0.885               160mp: 0.885             hs25exr: 0.882
# 11      casebook: 0.826               incas: 0.820             zenbook: 0.818
# 12         wiggl: 0.805             gamecub: 0.797            gameclub: 0.793
# 13    ao722c53kk: 0.851  as7739zp624g50mikk: 0.849  as5749zb964g50mnkk: 0.849
# 14        ipadst: 0.915           skipadclr: 0.859                 3rd: 0.848
# 15         754gb: 0.847                24gb: 0.834                 9gb: 0.830
# 16       blackic: 0.871              blaclr: 0.866           blackplum: 0.864
# 17       pharaoh: 0.823            parachut: 0.820           raccoonus: 0.819
# 18  wireless150n: 0.926        wireless300n: 0.924        wirelessmimo: 0.922
# 19      usbawc11: 0.830               usb20: 0.822             14tousb: 0.822
#
#                           10
# 0           mfc8480dn: 0.839
# 1         windtunnel™: 0.868
# 2             earphon: 0.842
# 3             ab10176: 0.847
# 4                  4g: 0.821
# 5          appleiphon: 0.797
# 6                wamd: 0.901
# 7     builtindishwash: 0.781
# 8              eos40d: 0.801
# 9                gumi: 0.790
# 10            f660exr: 0.878
# 11          toughbook: 0.813
# 12                3ds: 0.788
# 13  as57502634g64mnkk: 0.847
# 14          skipadpnk: 0.847
# 15         dt10816gbz: 0.829
# 16         blackfluro: 0.861
# 17             krabbi: 0.819
# 18          wirelessg: 0.913
# 19              cdusb: 0.822

# %% [markdown]
# ### minCount = 10

# %%
run_exp(minCount=10)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc10 -minCount 10
# Read 1M words
# Number of words:  6048
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   55999 lr:  0.000000 avg.loss:  1.415825 ETA:   0h 0m 0s
# + fasttext nn title_model.mc10.bin
#                          0                          1   \
# 0         Printer (printer)  printercopierscann: 0.860
# 1           Vaccum (vaccum)             vacmast: 0.846
# 2     Headphones (headphon)              earbud: 0.881
# 3    Binoculars (binocular)               scope: 0.787
# 4            Phones (phone)               phono: 0.804
# 5              Apple (appl)             appleâ®: 0.814
# 6                 AMD (amd)             athlon™: 0.904
# 7             Bosch (bosch)             ascenta: 0.846
# 8             Canon (canon)                  eo: 0.791
# 9   Skullcandy (skullcandi)               skull: 0.907
# 10        FinePix (finepix)            fujifilm: 0.939
# 11        Macbook (macbook)            macbook®: 0.949
# 12                Wii (wii)            nintendo: 0.880
# 13           Aspire (aspir)                n270: 0.748
# 14              Ipad (ipad)               ipad®: 0.936
# 15              16GB (16gb)                32gb: 0.878
# 16            Black (black)           blackwhit: 0.798
# 17            Bonus (bonus)             halflif: 0.751
# 18      Wireless (wireless)           wirelessg: 0.860
# 19                USB (usb)             drivest: 0.707
#
#                                 2                 3                   4   \
# 0   printercopierscannerfax: 0.860  officejet: 0.818       copier: 0.797
# 1                       vac: 0.842     vacuum: 0.840      foodsav: 0.830
# 2                overtheear: 0.871     yurbud: 0.836  overthehead: 0.791
# 3                    barska: 0.786    bushnel: 0.763       pentax: 0.706
# 4                    gophon: 0.780     huawei: 0.775      kyocera: 0.760
# 5                    apple®: 0.805        app: 0.714        moshi: 0.646
# 6                   phenom™: 0.898   sempron™: 0.881         tl60: 0.880
# 7                   integra: 0.754         67: 0.731      accubak: 0.730
# 8                       60d: 0.771        50d: 0.764           7d: 0.764
# 9                      inkd: 0.792       hesh: 0.789       earbud: 0.775
# 10                      z37: 0.924       xp20: 0.923          z90: 0.914
# 11                 bookendz: 0.799        154: 0.773   powerbook®: 0.761
# 12                nintendog: 0.869         ds: 0.797         wwii: 0.795
# 13                      116: 0.747    sapphir: 0.730     i72670qm: 0.721
# 14                    ipad™: 0.866        3rd: 0.805        folio: 0.781
# 15                      8gb: 0.859       64gb: 0.810          4gb: 0.736
# 16               blackpurpl: 0.776     blackr: 0.757     blacktop: 0.738
# 17                    zombi: 0.746    mermaid: 0.741        mysim: 0.732
# 18                wirelessn: 0.778    keyless: 0.681       80211g: 0.658
# 19                     3020: 0.682  20firewir: 0.681     jumpdriv: 0.657
#
#                    5                    6                     7   \
# 0       inkjet: 0.791       deskjet: 0.786          pixma: 0.782
# 1          vax: 0.823    windtunnel: 0.816        bagless: 0.806
# 2    noiseisol: 0.780       earphon: 0.766  behindtheneck: 0.761
# 3         2060: 0.705      circular: 0.691        popular: 0.660
# 4          att: 0.755     smartphon: 0.750         xperia: 0.750
# 5        aviiq: 0.630           3gs: 0.629             kb: 0.623
# 6      turion™: 0.877       quadcor: 0.858            3gb: 0.851
# 7       maytag: 0.726          2378: 0.725        tassimo: 0.722
# 8          t2i: 0.757         pixma: 0.756            t1i: 0.753
# 9       lowrid: 0.755        smokin: 0.746       headphon: 0.731
# 10        m863: 0.874           l18: 0.870            l22: 0.869
# 11          g4: 0.740        maccas: 0.716        macbeth: 0.712
# 12     gamecub: 0.744           360: 0.733       challeng: 0.727
# 13    obsidian: 0.719       ideapad: 0.718         nettop: 0.711
# 14   portfolio: 0.780  ipad®netbook: 0.774         hadaki: 0.727
# 15         6gb: 0.719          12gb: 0.703       jumpdriv: 0.695
# 16  whiteblack: 0.735     blackpink: 0.729     blackorang: 0.726
# 17       kirbi: 0.723        beyond: 0.722           poni: 0.721
# 18      80211b: 0.657          m305: 0.637         80211n: 0.630
# 19          20: 0.651       20esata: 0.648             j5: 0.638
#
#                       8                        9                 10
# 0         hl2170w: 0.781             print: 0.770   laserjet: 0.765
# 1         filtret: 0.801            canist: 0.799  ironsatin: 0.794
# 2     noisecancel: 0.754     behindthehead: 0.742       hesh: 0.733
# 3       celestron: 0.655        altazimuth: 0.635         kx: 0.618
# 4          captiv: 0.743            tmobil: 0.742       palm: 0.735
# 5            aiwa: 0.619          bookendz: 0.619    ipod®hd: 0.618
# 6         dualcor: 0.835                x6: 0.833   pentium®: 0.829
# 7            50lb: 0.721  blackonstainless: 0.720    woodlik: 0.720
# 8              xs: 0.753             hfr10: 0.752         5d: 0.746
# 9            gumi: 0.730              isol: 0.727      aviat: 0.718
# 10        sx230hs: 0.864             vg140: 0.863      m1063: 0.861
# 11          incas: 0.709                kb: 0.707         a7: 0.706
# 12            3ds: 0.715              xbox: 0.699   showdown: 0.698
# 13         velvet: 0.704          biscotti: 0.703      t5550: 0.697
# 14        generat: 0.719             bodhi: 0.708      easel: 0.707
# 15            2gb: 0.692             256gb: 0.691         cf: 0.669
# 16  blackgraywhit: 0.723         blackgold: 0.722  blacksilv: 0.720
# 17          zelda: 0.717             vacat: 0.713     unreal: 0.710
# 18           m325: 0.627             24ghz: 0.621       wiex: 0.602
# 19            kvm: 0.631           firewir: 0.628  barracuda: 0.625

# %% [markdown]
# ### minCount = 20

# %%
run_exp(minCount=20)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc20 -minCount 20
# Read 1M words
# Number of words:  3919
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   58111 lr:  0.000000 avg.loss:  1.453215 ETA:   0h 0m 0s
# + fasttext nn title_model.mc20.bin
#                          0                          1                  2   \
# 0         Printer (printer)  printercopierscann: 0.848     deskjet: 0.784
# 1           Vaccum (vaccum)              vacuum: 0.815         vac: 0.792
# 2     Headphones (headphon)              earbud: 0.868  overtheear: 0.859
# 3    Binoculars (binocular)              barska: 0.809       scope: 0.791
# 4            Phones (phone)              gophon: 0.793     kyocera: 0.779
# 5              Apple (appl)             appleâ®: 0.774      apple®: 0.742
# 6                 AMD (amd)             athlon™: 0.872     phenom™: 0.866
# 7             Bosch (bosch)             ascenta: 0.812          67: 0.753
# 8             Canon (canon)                  eo: 0.797         40d: 0.786
# 9   Skullcandy (skullcandi)                inkd: 0.807        hesh: 0.800
# 10        FinePix (finepix)            fujifilm: 0.936        m893: 0.860
# 11        Macbook (macbook)            macbook®: 0.948         154: 0.783
# 12                Wii (wii)            nintendo: 0.881          ds: 0.823
# 13           Aspire (aspir)                 116: 0.744        acer: 0.737
# 14              Ipad (ipad)               ipad®: 0.927       ipad™: 0.842
# 15              16GB (16gb)                32gb: 0.866         8gb: 0.846
# 16            Black (black)           blackwhit: 0.772      blackr: 0.747
# 17            Bonus (bonus)                payn: 0.778        hoyl: 0.697
# 18      Wireless (wireless)           wirelessg: 0.854   wirelessn: 0.782
# 19                USB (usb)                3020: 0.659    jumpdriv: 0.656
#
#                    3                 4                   5   \
# 0    officejet: 0.777   eallinon: 0.774       copier: 0.767
# 1      foodsav: 0.791    filtret: 0.782       canist: 0.778
# 2      earphon: 0.797  noiseisol: 0.757  noisecancel: 0.750
# 3      bushnel: 0.739  celestron: 0.689         mead: 0.646
# 4          att: 0.763       razr: 0.761         8530: 0.753
# 5          3gs: 0.643     hurley: 0.631        moshi: 0.620
# 6      turion™: 0.853   sempron™: 0.845         tl60: 0.833
# 7      integra: 0.751       2378: 0.704      tassimo: 0.699
# 8          50d: 0.785        60d: 0.775           7d: 0.773
# 9       earbud: 0.793     lowrid: 0.775       smokin: 0.772
# 10     coolpix: 0.847       s210: 0.838        140mp: 0.837
# 11  powerbook®: 0.759         g4: 0.754      macbeth: 0.706
# 12        wwii: 0.798    gamecub: 0.748          3ds: 0.740
# 13        n270: 0.728   obsidian: 0.721      spinner: 0.682
# 14   portfolio: 0.764        3rd: 0.758        folio: 0.754
# 15        64gb: 0.786        4gb: 0.745         12gb: 0.715
# 16  whiteblack: 0.737  pinkblack: 0.730     redblack: 0.707
# 17      beyond: 0.692     museum: 0.681      journey: 0.677
# 18      router: 0.600     80211g: 0.597       80211b: 0.594
# 19          20: 0.652     iomega: 0.644        drive: 0.643
#
#                          6                     7                  8   \
# 0              pixma: 0.760        scanjet: 0.756      inkjet: 0.748
# 1            bagless: 0.778         eureka: 0.752  windtunnel: 0.752
# 2                bud: 0.740  behindtheneck: 0.726        hesh: 0.719
# 3             pentax: 0.636       circular: 0.631      deterg: 0.580
# 4               8520: 0.752             4g: 0.748    motorola: 0.748
# 5              mophi: 0.603             3g: 0.592       3g3gs: 0.585
# 6            quadcor: 0.819            3gb: 0.809          x4: 0.808
# 7   blackonstainless: 0.686       dishwash: 0.686   architect: 0.680
# 8              pixma: 0.771            xsi: 0.765          ef: 0.762
# 9             touch®: 0.746            bud: 0.744       nano®: 0.712
# 10             s3100: 0.835           m863: 0.833       s4100: 0.823
# 11             moshi: 0.688        timbuk2: 0.675        nook: 0.661
# 12          challeng: 0.716         rabbid: 0.712    showdown: 0.699
# 13          inspiron: 0.676        sapphir: 0.674     ideapad: 0.672
# 14      ipad®netbook: 0.716          easel: 0.709       bodhi: 0.691
# 15               2gb: 0.706            6gb: 0.704          gb: 0.689
# 16        blackorang: 0.705      blackpink: 0.703   blueblack: 0.702
# 17             zelda: 0.674        paradis: 0.673       resid: 0.673
# 18          dualband: 0.539          24ghz: 0.534     gamepad: 0.530
# 19            goflex: 0.607          flash: 0.596  ipod®ipad®: 0.592
#
#                     9                  10
# 0      laserjet: 0.743      s51204: 0.737
# 1        hoover: 0.722      irobot: 0.720
# 2    skullcandi: 0.711         2xl: 0.711
# 3         146mp: 0.578  waterproof: 0.577
# 4       verizon: 0.745   smartphon: 0.744
# 5         iphon: 0.571        ipod: 0.571
# 6            x2: 0.793     dualcor: 0.771
# 7     whirlpool: 0.677   washerdry: 0.671
# 8           t2i: 0.761          xs: 0.759
# 9      headphon: 0.711        ipod: 0.711
# 10         w530: 0.822       m1063: 0.818
# 11        incas: 0.659    playbook: 0.655
# 12        mysim: 0.698         360: 0.691
# 13      emachin: 0.663    biscotti: 0.663
# 14      generat: 0.678      apple®: 0.674
# 15       memori: 0.682       256gb: 0.668
# 16  blackyellow: 0.690   blacksilv: 0.687
# 17          paw: 0.669       mysim: 0.668
# 18         wire: 0.523     5button: 0.521
# 19      attaché: 0.591       2port: 0.589

# %% [markdown]
# ### minCount = 50

# %%
run_exp(minCount=50)
# Out:
# + fasttext skipgram -input titles.txt -output title_model.mc50 -minCount 50
# Read 1M words
# Number of words:  2167
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   68669 lr:  0.000000 avg.loss:  1.446406 ETA:   0h 0m 0s
# + fasttext nn title_model.mc50.bin
#                          0                 1                   2   \
# 0         Printer (printer)  officejet: 0.799       inkjet: 0.797
# 1           Vaccum (vaccum)     vacuum: 0.866          vac: 0.857
# 2     Headphones (headphon)     earbud: 0.859   overtheear: 0.834
# 3    Binoculars (binocular)      scope: 0.799      bushnel: 0.781
# 4            Phones (phone)       razr: 0.750      kyocera: 0.733
# 5              Apple (appl)     apple®: 0.774          3gs: 0.600
# 6                 AMD (amd)    athlon™: 0.911      turion™: 0.865
# 7             Bosch (bosch)         67: 0.710       maytag: 0.676
# 8             Canon (canon)         eo: 0.803          xsi: 0.777
# 9   Skullcandy (skullcandi)     earbud: 0.748         gumi: 0.715
# 10        FinePix (finepix)   fujifilm: 0.937        140mp: 0.810
# 11        Macbook (macbook)   macbook®: 0.947        incas: 0.650
# 12                Wii (wii)   nintendo: 0.858           ds: 0.774
# 13           Aspire (aspir)       acer: 0.721          116: 0.715
# 14              Ipad (ipad)      ipad®: 0.920        ipad™: 0.822
# 15              16GB (16gb)       32gb: 0.841          8gb: 0.832
# 16            Black (black)  blacksilv: 0.732    blackwhit: 0.730
# 17            Bonus (bonus)      sanus: 0.736  martinlogan: 0.675
# 18      Wireless (wireless)  wirelessg: 0.824    wirelessn: 0.734
# 19                USB (usb)     iomega: 0.629           20: 0.615
#
#                     3                 4                    5   \
# 0         pixma: 0.786     copier: 0.767  networkreadi: 0.740
# 1       bagless: 0.832     canist: 0.813        eureka: 0.784
# 2   noisecancel: 0.754        bud: 0.734           akg: 0.709
# 3        barska: 0.780  celestron: 0.730        pentax: 0.683
# 4       pantech: 0.732         4g: 0.730           att: 0.716
# 5         ipod®: 0.545      iphon: 0.542         moshi: 0.530
# 6       phenom™: 0.848        3gb: 0.825            x4: 0.793
# 7     whirlpool: 0.671  architect: 0.658    electrolux: 0.650
# 8           t2i: 0.775      pixma: 0.774            7d: 0.769
# 9           bud: 0.711      nano®: 0.704          ipod: 0.704
# 10      coolpix: 0.804      lumix: 0.798          fuji: 0.793
# 11      seethru: 0.628    neopren: 0.628         speck: 0.621
# 12     challeng: 0.735        360: 0.726          xbox: 0.698
# 13      ideapad: 0.678   inspiron: 0.666       emachin: 0.641
# 14          3rd: 0.786  portfolio: 0.753         folio: 0.717
# 15         64gb: 0.778        6gb: 0.697           4gb: 0.694
# 16       blackr: 0.722   redblack: 0.693    whiteblack: 0.675
# 17       inceil: 0.673       bond: 0.667         sonax: 0.658
# 18       80211g: 0.540     router: 0.520         24ghz: 0.517
# 19       goflex: 0.600      drive: 0.600           hub: 0.599
#
#                   6                    7                  8   \
# 0    laserjet: 0.735         print: 0.721         fax: 0.715
# 1      wetdri: 0.768        hoover: 0.767     filtret: 0.757
# 2         ear: 0.700         inear: 0.699  skullcandi: 0.694
# 3        spot: 0.610      telescop: 0.599           x: 0.583
# 4    ericsson: 0.712         nokia: 0.708      tmobil: 0.705
# 5     iphone®: 0.529            3g: 0.527    macbook®: 0.510
# 6          x2: 0.792      pentium®: 0.785     dualcor: 0.762
# 7      evolut: 0.647     washerdry: 0.645    dishwash: 0.641
# 8         t3i: 0.763         rebel: 0.761         t1i: 0.761
# 9    headphon: 0.694        touch®: 0.686      ifrogz: 0.653
# 10     exilim: 0.775          elph: 0.769    easyshar: 0.765
# 11   claiborn: 0.620           133: 0.614     ideapad: 0.611
# 12    gamecub: 0.697         puzzl: 0.670      hasbro: 0.667
# 13   thinkpad: 0.638      celeron®: 0.633         msi: 0.626
# 14    generat: 0.650        apple®: 0.631       sleev: 0.619
# 15        2gb: 0.663         128gb: 0.609      memori: 0.607
# 16  blackgray: 0.665     blueblack: 0.662    blackblu: 0.633
# 17  bookshelf: 0.641  polypropylen: 0.639      whalen: 0.637
# 18    gamepad: 0.482     cinemanow: 0.473        wire: 0.472
# 19    firewir: 0.586         4port: 0.577      seagat: 0.571
#
#                    9                   10
# 0   photosmart: 0.712      lexmark: 0.712
# 1       bissel: 0.714         hepa: 0.700
# 2       clipon: 0.673    microphon: 0.664
# 3         zoom: 0.560   waterproof: 0.560
# 4     cellstar: 0.705    smartphon: 0.684
# 5      squier®: 0.506         ipod: 0.502
# 6          msi: 0.758           64: 0.730
# 7   cleansteel: 0.640       profil: 0.629
# 8      55250mm: 0.754          60d: 0.753
# 9      armband: 0.643     4thgener: 0.605
# 10       120mp: 0.761    powershot: 0.756
# 11        pros: 0.609          3gs: 0.608
# 12        petz: 0.657          3ds: 0.656
# 13   ideacentr: 0.623          156: 0.618
# 14     iphone®: 0.603           4s: 0.598
# 15          gb: 0.605          60d: 0.567
# 16  blackgreen: 0.614  silverblack: 0.604
# 17        polk: 0.631   floorstand: 0.611
# 18     keyscap: 0.463       access: 0.459
# 19      extern: 0.555      skatedr: 0.553
