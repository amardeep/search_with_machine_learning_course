# %%
import pexpect
import pandas as pd
import subprocess
import string
import nltk
from nltk.stem.snowball import SnowballStemmer

# %%
# %cd /workspace/datasets/fasttext
# Out:
# /home/jupyter/.kaggle/datasets/fasttext

# %% [markdown]
# ### Extract titles to phone_titles.txt

# %%
# %%bash
# set -x
# python /workspace/search_with_machine_learning_course/week3/extractTitles.py \
#     --products_df /workspace/datasets/fasttext/phone_products_df.pk \
#     --output /workspace/datasets/fasttext/phone_titles.txt \
#     --sample_rate 1.0
# wc -l /workspace/datasets/fasttext/phone_titles.txt
# Out:
# + python /workspace/search_with_machine_learning_course/week3/extractTitles.py --products_df /workspace/datasets/fasttext/phone_products_df.pk --output /workspace/datasets/fasttext/phone_titles.txt --sample_rate 1.0
# Writing results to /workspace/datasets/fasttext/phone_titles.txt
# + wc -l /workspace/datasets/fasttext/phone_titles.txt
# 4862 /workspace/datasets/fasttext/phone_titles.txt

# %% [markdown]
# ### Text transformation

# %%
translation_table = str.maketrans("", "", "®©™" + string.punctuation)

def transform_training_data(name):
    name = name.replace("\n", " ")
    name = name.lower()
    # remove punctuation
    name = name.translate(translation_table)
    tokens = nltk.word_tokenize(name)
    stemmer = SnowballStemmer("english")
    tokens = [stemmer.stem(t) for t in tokens]
    return " ".join(tokens)

# %% [markdown]
# ### Words used for evaluation

# %%
words = [
    "fabshell", "hurley", "bluetrek", "energi",
    "apple", "iphone", "samsung", "motorola", "headphones",
    "galaxy", "droid", "ericsson", "microsd", "razr",
    "case", "protector", "leather", "charger", "unlocked"
]

# %% [markdown]
# ### Evaluation

# %%
def run_exp(epochs=25, minCount = 5):
    # Train model
    dir = "/workspace/datasets/fasttext/"
    model = f"phone_title_model.e{epochs}.mc{minCount}"
    cmd = f"fasttext skipgram -input phone_titles.txt -output {model} -epoch {epochs} -minCount {minCount}"
    print(f"+ {cmd}")
    subprocess.run(cmd, shell=True, cwd=dir)

    # Eval on words
    rows = []
    cmd = f"fasttext nn {model}.bin"
    print(f"+ {cmd}")
    child=pexpect.spawn(cmd, encoding='utf-8')
    child.expect('Query word?')
    for input_word in words:
        word = transform_training_data(input_word)
        child.sendline(word)
        child.expect('Query word?')
        output = child.before
        lines = output.strip().split("\r\n")[1:]
        splits = [line.strip().split() for line in lines]
        row = [f"{input_word} ({word})"] + [f"{o[0]}: {float(o[1]):.3f}" for o in splits]
        rows.append(row)
    child.close()
    df = pd.DataFrame(rows)
    display(df)

# %% [markdown]
# #### Epochs = 25, Min Count = 5

# %% [markdown]
# Base model with epochs = 25 and min count = 5. As this is a pretty small dataset, it didn't feel like increasing min count any further will benefit.

# %%
run_exp(epochs=25)
# Out:
# + fasttext skipgram -input phone_titles.txt -output phone_title_model.e25.mc5 -epoch 25 -minCount 5
# Read 0M words
# Number of words:  673
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  192072 lr:  0.000000 avg.loss:  2.250995 ETA:   0h 0m 0s
# + fasttext nn phone_title_model.e25.mc5.bin
#                        0                 1                      2   \
# 0      fabshell (fabshel)  candyshel: 0.982           speck: 0.966
# 1         hurley (hurley)     oakley: 0.980  harleydavidson: 0.966
# 2     bluetrek (bluetrek)    blueant: 0.979       bluetooth: 0.974
# 3         energi (energi)      energ: 0.978           emerg: 0.884
# 4            apple (appl)    fabshel: 0.939       candyshel: 0.931
# 5          iphone (iphon)       appl: 0.931               4: 0.902
# 6       samsung (samsung)         ii: 0.902          galaxi: 0.896
# 7     motorola (motorola)         v3: 0.907            razr: 0.907
# 8   headphones (headphon)  earpollut: 0.985          earbud: 0.959
# 9         galaxy (galaxi)        iii: 0.936               s: 0.930
# 10          droid (droid)          x: 0.919          bionic: 0.879
# 11    ericsson (ericsson)       soni: 0.945       cybershot: 0.942
# 12      microsd (microsd)  microsdhc: 0.996         sandisk: 0.978
# 13            razr (razr)         v3: 0.918        motorola: 0.907
# 14            case (case)      sleev: 0.829          moment: 0.814
# 15  protector (protector)     screen: 0.970         protect: 0.902
# 16      leather (leather)      carri: 0.917          jensen: 0.893
# 17      charger (charger)     vehicl: 0.896          travel: 0.882
# 18      unlocked (unlock)  cybershot: 0.870        titanium: 0.821
#
#                     3                       4                 5   \
# 0        bumper: 0.963         hardshel: 0.958     burton: 0.957
# 1       macbeth: 0.950            kapok: 0.940    fabshel: 0.931
# 2   bluetoothen: 0.966  bluetoothcompat: 0.962  discoveri: 0.918
# 3         devic: 0.864          mycharg: 0.857         to: 0.854
# 4         iphon: 0.931             teal: 0.930      kapok: 0.926
# 5            4s: 0.890          fabshel: 0.880  candyshel: 0.878
# 6        indulg: 0.894             epic: 0.882      nexus: 0.873
# 7          purs: 0.848            droid: 0.797    superex: 0.796
# 8     microphon: 0.939             ozon: 0.933        lux: 0.932
# 9          epic: 0.913       multimedia: 0.898    samsung: 0.896
# 10         a957: 0.870           fascin: 0.863         x2: 0.858
# 11      walkman: 0.923           xperia: 0.913        x10: 0.901
# 12         sdhc: 0.967            stick: 0.960      class: 0.959
# 13         purs: 0.873       swivelclip: 0.840     swivel: 0.831
# 14    blackpink: 0.811         pinkwhit: 0.809  pinkblack: 0.803
# 15       surfac: 0.891          maximum: 0.885       zagg: 0.857
# 16         purs: 0.877           madden: 0.868         v3: 0.861
# 17        innov: 0.857             wall: 0.848      rapid: 0.835
# 18     sidekick: 0.814              e71: 0.810  whitesilv: 0.805
#
#                  6                  7                       8   \
# 0     oakley: 0.955       kapok: 0.949   harleydavidson: 0.946
# 1    tekkeon: 0.927   candyshel: 0.925         hardshel: 0.918
# 2     explor: 0.914       jabra: 0.906         plantron: 0.903
# 3   electron: 0.848     recharg: 0.822          callpod: 0.819
# 4     bumper: 0.912      oakley: 0.908         hardshel: 0.905
# 5      kapok: 0.867     tekkeon: 0.866   harleydavidson: 0.861
# 6      focus: 0.866     graviti: 0.866              iii: 0.854
# 7       a855: 0.793      bionic: 0.790            rapid: 0.789
# 8     ifrogz: 0.924       onear: 0.909           jammin: 0.907
# 9         ii: 0.888      captiv: 0.887             note: 0.875
# 10     atrix: 0.850  rocketfish: 0.850          android: 0.836
# 11       eri: 0.772        dell: 0.759           replac: 0.736
# 12     lexar: 0.959      extrem: 0.956              pni: 0.954
# 13  backflip: 0.801        krzr: 0.798             a855: 0.793
# 14     plaid: 0.802        snap: 0.797      antibacteri: 0.794
# 15    fascin: 0.855     sphm850: 0.851  invisibleshield: 0.845
# 16       esi: 0.855      milant: 0.854             espn: 0.851
# 17      just: 0.802        dual: 0.801               ac: 0.793
# 18       x10: 0.799      flight: 0.792          walkman: 0.792
#
#                  9                 10
# 0       teal: 0.942       appl: 0.939
# 1       gaga: 0.916         4s: 0.911
# 2        era: 0.895     stereo: 0.887
# 3        gps: 0.819        usb: 0.805
# 4         4s: 0.905      speck: 0.903
# 5   hardshel: 0.858     oakley: 0.856
# 6          t: 0.840     status: 0.839
# 7   backflip: 0.778      innov: 0.771
# 8     marley: 0.891         33: 0.874
# 9      nexus: 0.867      pebbl: 0.852
# 10      a855: 0.820      vivid: 0.814
# 11    unlock: 0.734   clearvox: 0.719
# 12     capac: 0.954        2gb: 0.952
# 13  cellsuit: 0.778       clip: 0.767
# 14   silicon: 0.793      versa: 0.793
# 15     cover: 0.836  softtouch: 0.831
# 16     pouch: 0.849    superex: 0.848
# 17     charg: 0.791        car: 0.783
# 18     pearl: 0.790      lumia: 0.782

# %% [markdown]
# #### Comparing epochs = 5, 25, 50, 100
#
# Running with 5 epochs results in all scores > .999. So, that can be safely excluded.
#
# Between 25, 50, and 100 though, it is not clear which one to pick, and how to decide which is better. Also
# even when relative order of nearest neighbors remain same, scores change a lot with no. of epochs. So threshold
# score is dependent on no. of epochs.

# %%
run_exp(epochs=5)
run_exp(epochs=25)
run_exp(epochs=50)
run_exp(epochs=100)
# Out:
# + fasttext skipgram -input phone_titles.txt -output phone_title_model.e5.mc5 -epoch 5 -minCount 5
# Read 0M words
# Number of words:  673
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  183308 lr:  0.000000 avg.loss:  3.072129 ETA:   0h 0m 0s
# + fasttext nn phone_title_model.e5.mc5.bin
#                        0                   1                       2   \
# 0      fabshell (fabshel)     hardshel: 1.000        candyshel: 1.000
# 1         hurley (hurley)       marley: 1.000   harleydavidson: 1.000
# 2     bluetrek (bluetrek)    bluetooth: 1.000          blueant: 1.000
# 3         energi (energi)        energ: 1.000          graphit: 1.000
# 4            apple (appl)          3gs: 1.000            incas: 1.000
# 5          iphone (iphon)       gophon: 1.000            3g3gs: 1.000
# 6       samsung (samsung)      mytouch: 1.000        softtouch: 1.000
# 7     motorola (motorola)        nokia: 1.000          desktop: 1.000
# 8   headphones (headphon)       gophon: 1.000           marley: 1.000
# 9         galaxy (galaxi)     interfac: 1.000       nocontract: 1.000
# 10          droid (droid)      android: 1.000           xentri: 1.000
# 11    ericsson (ericsson)       wilson: 1.000       multicolor: 1.000
# 12      microsd (microsd)    microsdhc: 1.000            micro: 1.000
# 13            razr (razr)      vibrant: 1.000        processor: 1.000
# 14            case (case)        casem: 1.000         otterbox: 1.000
# 15  protector (protector)      protect: 1.000  invisibleshield: 1.000
# 16      leather (leather)      station: 1.000            smart: 1.000
# 17      charger (charger)        charg: 1.000          recharg: 1.000
# 18      unlocked (unlock)  silverblack: 1.000             dock: 1.000
#
#                     3                   4                   5   \
# 0         purpl: 1.000   multicolor: 1.000      silicon: 1.000
# 1    rocketfish: 1.000       madden: 1.000       incred: 1.000
# 2   bluetoothen: 1.000         blue: 1.000     bluesilv: 1.000
# 3        madden: 1.000        multi: 1.000   multicolor: 1.000
# 4         iphon: 1.000         ipod: 1.000        3g3gs: 1.000
# 5          appl: 1.000          3gs: 1.000        incas: 1.000
# 6        silver: 1.000       unlock: 1.000        nokia: 1.000
# 7    multimedia: 1.000    softtouch: 1.000       surfac: 1.000
# 8        earbud: 1.000    earpollut: 1.000  speakerphon: 1.000
# 9      horizont: 1.000   multicolor: 1.000       laptop: 1.000
# 10      monster: 1.000  thunderbolt: 1.000      desktop: 1.000
# 11      station: 1.000     electron: 1.000     pinkwhit: 1.000
# 12         sdhc: 1.000       memori: 1.000          8gb: 1.000
# 13        union: 1.000      pantech: 1.000     horizont: 1.000
# 14        incas: 1.000       defend: 1.000     hardshel: 1.000
# 15      vibrant: 1.000   multimedia: 1.000    processor: 1.000
# 16      duracel: 1.000       fellow: 1.000       impact: 1.000
# 17      mycharg: 1.000      desktop: 1.000     charcoal: 1.000
# 18       silver: 1.000      vibrant: 1.000      station: 1.000
#
#                         6                   7                      8   \
# 0    harleydavidson: 1.000   rocketfish: 1.000         graphit: 1.000
# 1           antenna: 1.000   multicolor: 1.000     speakerphon: 1.000
# 2   bluetoothcompat: 1.000     bluewhit: 1.000             blu: 1.000
# 3        multimedia: 1.000    accessori: 1.000           brown: 1.000
# 4                4s: 1.000        purpl: 1.000           stand: 1.000
# 5           macbeth: 1.000    smartphon: 1.000        headphon: 1.000
# 6            galaxi: 1.000   multicolor: 1.000         desktop: 1.000
# 7            design: 1.000        model: 1.000         monster: 1.000
# 8                on: 1.000    smartphon: 1.000  harleydavidson: 1.000
# 9        multimedia: 1.000     instinct: 1.000     stratospher: 1.000
# 10           silver: 1.000    softtouch: 1.000         vibrant: 1.000
# 11         interfac: 1.000  thunderbolt: 1.000          credit: 1.000
# 12             high: 1.000        class: 1.000             4gb: 1.000
# 13          univers: 1.000        orang: 1.000           devic: 1.000
# 14        blackwhit: 1.000        speck: 1.000         silicon: 1.000
# 15           packag: 1.000        green: 1.000           intel: 1.000
# 16       multicolor: 1.000       silver: 1.000        instinct: 1.000
# 17           player: 1.000     cellstar: 1.000        motorola: 1.000
# 18        softtouch: 1.000    blacksilv: 1.000         mytouch: 1.000
#
#                         9                      10
# 0           control: 1.000        pinkwhit: 1.000
# 1         accessori: 1.000        pinkwhit: 1.000
# 2           univers: 1.000         station: 1.000
# 3            instal: 1.000       processor: 1.000
# 4           macbeth: 1.000        hardshel: 1.000
# 5              3g3g: 1.000           purpl: 1.000
# 6             solar: 1.000      multimedia: 1.000
# 7   bluetoothcompat: 1.000         univers: 1.000
# 8              ozon: 1.000       microphon: 1.000
# 9         intercept: 1.000        internet: 1.000
# 10          antenna: 1.000          intens: 1.000
# 11          control: 1.000  harleydavidson: 1.000
# 12              2gb: 1.000       microphon: 1.000
# 13          station: 1.000         antenna: 1.000
# 14        lifeproof: 1.000           purpl: 1.000
# 15           instal: 1.000           multi: 1.000
# 16       rocketfish: 1.000         desktop: 1.000
# 17             just: 1.000         univers: 1.000
# 18         interfac: 1.000        titanium: 1.000
# + fasttext skipgram -input phone_titles.txt -output phone_title_model.e25.mc5 -epoch 25 -minCount 5
# Read 0M words
# Number of words:  673
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  192191 lr:  0.000000 avg.loss:  2.222176 ETA:   0h 0m 0s
# + fasttext nn phone_title_model.e25.mc5.bin
#                        0                 1                      2   \
# 0      fabshell (fabshel)  candyshel: 0.982           kapok: 0.971
# 1         hurley (hurley)     oakley: 0.982  harleydavidson: 0.969
# 2     bluetrek (bluetrek)    blueant: 0.974       bluetooth: 0.971
# 3         energi (energi)      energ: 0.982           devic: 0.883
# 4            apple (appl)      kapok: 0.947           iphon: 0.944
# 5          iphone (iphon)       appl: 0.944               4: 0.915
# 6       samsung (samsung)       epic: 0.874              ii: 0.874
# 7     motorola (motorola)         v3: 0.900            razr: 0.885
# 8   headphones (headphon)  earpollut: 0.982          earbud: 0.959
# 9         galaxy (galaxi)        iii: 0.952               s: 0.927
# 10          droid (droid)          x: 0.898          fascin: 0.874
# 11    ericsson (ericsson)       soni: 0.957       cybershot: 0.932
# 12      microsd (microsd)  microsdhc: 0.996         sandisk: 0.975
# 13            razr (razr)         v3: 0.914        motorola: 0.885
# 14            case (case)        for: 0.829           sleev: 0.810
# 15  protector (protector)     screen: 0.967         protect: 0.898
# 16      leather (leather)      carri: 0.902          jensen: 0.890
# 17      charger (charger)     vehicl: 0.914          travel: 0.869
# 18      unlocked (unlock)  cybershot: 0.872        titanium: 0.826
#
#                     3                       4                  5   \
# 0         speck: 0.971           bumper: 0.970      oakley: 0.969
# 1         kapok: 0.950          macbeth: 0.948     fabshel: 0.942
# 2   bluetoothen: 0.968  bluetoothcompat: 0.959   discoveri: 0.918
# 3         emerg: 0.879         electron: 0.871          to: 0.862
# 4       fabshel: 0.927             teal: 0.925   candyshel: 0.923
# 5         kapok: 0.892               4s: 0.887     fabshel: 0.885
# 6        galaxi: 0.870            nexus: 0.870      indulg: 0.867
# 7          purs: 0.829             a855: 0.780      bionic: 0.775
# 8     microphon: 0.940             ozon: 0.924      ifrogz: 0.921
# 9        captiv: 0.902             epic: 0.900          ii: 0.900
# 10           x2: 0.865           bionic: 0.865  rocketfish: 0.865
# 11      walkman: 0.923           xperia: 0.905         x10: 0.891
# 12         sdhc: 0.968            stick: 0.960       lexar: 0.954
# 13         purs: 0.867       swivelclip: 0.828      swivel: 0.813
# 14    blackpink: 0.802            casem: 0.801     silicon: 0.793
# 15       surfac: 0.891          maximum: 0.881      fascin: 0.862
# 16       milant: 0.881              esi: 0.879      madden: 0.872
# 17         wall: 0.852            innov: 0.845       rapid: 0.821
# 18     sidekick: 0.826           flight: 0.825   whitesilv: 0.809
#
#                   6                  7                      8   \
# 0    hardshel: 0.962      burton: 0.961  harleydavidson: 0.959
# 1     tekkeon: 0.929        gaga: 0.927       candyshel: 0.927
# 2      explor: 0.913         era: 0.902           jabra: 0.901
# 3     mycharg: 0.858     recharg: 0.827         callpod: 0.823
# 4      oakley: 0.918       video: 0.914          canopi: 0.913
# 5   candyshel: 0.885      oakley: 0.876         tekkeon: 0.873
# 6        note: 0.865     graviti: 0.864         vibrant: 0.831
# 7    cellular: 0.773     superex: 0.771          vehicl: 0.770
# 8         lux: 0.920      jammin: 0.910          marley: 0.899
# 9        note: 0.892       pebbl: 0.874           nexus: 0.870
# 10      atrix: 0.857     android: 0.852            a957: 0.851
# 11     replac: 0.730      select: 0.717             eri: 0.708
# 12        2gb: 0.953         pni: 0.953           capac: 0.952
# 13   backflip: 0.791        krzr: 0.788            a855: 0.786
# 14   pinkwhit: 0.791  blackclear: 0.789           2pack: 0.788
# 15          x: 0.861        zagg: 0.860          packag: 0.858
# 16       purs: 0.870         tan: 0.868           pouch: 0.852
# 17      charg: 0.807        dual: 0.798              ac: 0.797
# 18      pearl: 0.804         e71: 0.804          camera: 0.794
#
#                         9                  10
# 0            canopi: 0.956        teal: 0.950
# 1            canopi: 0.925    hardshel: 0.923
# 2            stereo: 0.898    plantron: 0.887
# 3              r225: 0.819        data: 0.814
# 4           tekkeon: 0.908      bumper: 0.906
# 5            canopi: 0.866      bumper: 0.866
# 6             googl: 0.829       focus: 0.814
# 7             innov: 0.769       carri: 0.766
# 8             onear: 0.897        hous: 0.887
# 9           samsung: 0.870  multimedia: 0.868
# 10                2: 0.825       vivid: 0.823
# 11             pdas: 0.708      unlock: 0.695
# 12           extrem: 0.952       class: 0.952
# 13            carri: 0.775        clip: 0.774
# 14           moment: 0.785   pinkblack: 0.784
# 15  invisibleshield: 0.852       cover: 0.846
# 16               v3: 0.848      vertic: 0.844
# 17          recharg: 0.792     desktop: 0.791
# 18              x10: 0.789     walkman: 0.789
# + fasttext skipgram -input phone_titles.txt -output phone_title_model.e50.mc5 -epoch 50 -minCount 5
# Read 0M words
# Number of words:  673
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  192262 lr:  0.000000 avg.loss:  1.872594 ETA:   0h 0m 0s
# + fasttext nn phone_title_model.e50.mc5.bin
#                        0                       1                   2   \
# 0      fabshell (fabshel)            speck: 0.938       burton: 0.938
# 1         hurley (hurley)           oakley: 0.914      macbeth: 0.902
# 2     bluetrek (bluetrek)  bluetoothcompat: 0.918  bluetoothen: 0.898
# 3         energi (energi)            energ: 0.945           go: 0.805
# 4            apple (appl)            iphon: 0.874            4: 0.829
# 5          iphone (iphon)             appl: 0.874           4s: 0.820
# 6       samsung (samsung)           galaxi: 0.706           ii: 0.633
# 7     motorola (motorola)             razr: 0.734        droid: 0.683
# 8   headphones (headphon)        earpollut: 0.923    microphon: 0.883
# 9         galaxy (galaxi)              iii: 0.851            s: 0.831
# 10          droid (droid)           bionic: 0.825       photon: 0.767
# 11    ericsson (ericsson)             soni: 0.919      walkman: 0.844
# 12      microsd (microsd)        microsdhc: 0.984      sandisk: 0.951
# 13            razr (razr)               v3: 0.787     motorola: 0.734
# 14            case (case)            casem: 0.611     pinkwhit: 0.568
# 15  protector (protector)           screen: 0.938      protect: 0.807
# 16      leather (leather)            carri: 0.751       jensen: 0.748
# 17      charger (charger)             wall: 0.792       vehicl: 0.784
# 18      unlocked (unlock)        cybershot: 0.686     titanium: 0.679
#
#                   3                       4                 5   \
# 0   candyshel: 0.905            plaid: 0.846    macbeth: 0.833
# 1        gaga: 0.880   harleydavidson: 0.874       ladi: 0.843
# 2   bluetooth: 0.891          blueant: 0.879    headset: 0.803
# 3    electron: 0.790           credit: 0.772      emerg: 0.771
# 4          4s: 0.791              3gs: 0.725      kapok: 0.695
# 5           4: 0.815              3gs: 0.751      kapok: 0.702
# 6         iii: 0.600                s: 0.583     indulg: 0.580
# 7          v3: 0.678             purs: 0.619     photon: 0.609
# 8      earbud: 0.858           jammin: 0.850       hous: 0.838
# 9        note: 0.816           captiv: 0.809         ii: 0.769
# 10          x: 0.750               x2: 0.750     devour: 0.736
# 11  cybershot: 0.844           xperia: 0.814        x10: 0.787
# 12        pni: 0.911            class: 0.910        2gb: 0.899
# 13       purs: 0.710           photon: 0.628     bionic: 0.618
# 14      plaid: 0.541             pink: 0.537  blackpink: 0.529
# 15    maximum: 0.762  invisibleshield: 0.736     packag: 0.729
# 16       espn: 0.675          essenti: 0.670        tan: 0.651
# 17     travel: 0.770            innov: 0.738         ac: 0.718
# 18  refurbish: 0.669              att: 0.658    walkman: 0.647
#
#                   6                7                   8   \
# 0      bumper: 0.824  hardshel: 0.807         puma: 0.807
# 1       venom: 0.843   tekkeon: 0.832  antibacteri: 0.824
# 2   discoveri: 0.776       era: 0.769          blu: 0.769
# 3          to: 0.767   mycharg: 0.755         edit: 0.724
# 4     tekkeon: 0.664    canopi: 0.658         teal: 0.648
# 5     tekkeon: 0.691    canopi: 0.669         teal: 0.652
# 6       nexus: 0.573      epic: 0.560        etern: 0.548
# 7        a855: 0.598     mb200: 0.583           x2: 0.581
# 8      marley: 0.824    ifrogz: 0.811          lux: 0.810
# 9        epic: 0.760     nexus: 0.747        marbl: 0.742
# 10      atrix: 0.732      a957: 0.707         a855: 0.691
# 11      rapid: 0.693    siemen: 0.620     clearvox: 0.620
# 12       sdhc: 0.894     stick: 0.892        capac: 0.880
# 13      droid: 0.601      krzr: 0.598         a855: 0.578
# 14        for: 0.519   ballist: 0.511           ed: 0.508
# 15       zagg: 0.728    surfac: 0.702      sphm850: 0.693
# 16   cellstar: 0.647       esi: 0.636       hipcas: 0.626
# 17    startac: 0.705     rapid: 0.685           dc: 0.676
# 18      sharp: 0.625  sidekick: 0.625            t: 0.619
#
#                      9                 10
# 0          frost: 0.805    tekkeon: 0.804
# 1        fabshel: 0.802       puma: 0.768
# 2          jabra: 0.768   midnight: 0.741
# 3   broadband2go: 0.711       bank: 0.705
# 4           gaga: 0.613     burton: 0.611
# 5          3g3gs: 0.648      incas: 0.626
# 6         intens: 0.541    sphm850: 0.537
# 7          atrix: 0.576          x: 0.552
# 8           ozon: 0.807         33: 0.780
# 9         indulg: 0.734      pebbl: 0.712
# 10       android: 0.686   motorola: 0.683
# 11       startac: 0.616        arm: 0.613
# 12           4gb: 0.858     extrem: 0.855
# 13       compani: 0.568   cliphang: 0.566
# 14         shell: 0.504       ladi: 0.503
# 15      fullbodi: 0.689          v: 0.676
# 16   brightpoint: 0.625        rim: 0.624
# 17       recharg: 0.675  xtrememac: 0.671
# 18         steel: 0.606     rubber: 0.598
# + fasttext skipgram -input phone_titles.txt -output phone_title_model.e100.mc5 -epoch 100 -minCount 5
# Read 0M words
# Number of words:  673
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  191604 lr:  0.000000 avg.loss:  1.462466 ETA:   0h 0m 0s
# + fasttext nn phone_title_model.e100.mc5.bin
#                        0                       1                      2   \
# 0      fabshell (fabshel)           burton: 0.921           speck: 0.879
# 1         hurley (hurley)           oakley: 0.838  harleydavidson: 0.812
# 2     bluetrek (bluetrek)  bluetoothcompat: 0.798     bluetoothen: 0.790
# 3         energi (energi)            energ: 0.895              go: 0.756
# 4            apple (appl)            iphon: 0.832               4: 0.665
# 5          iphone (iphon)             appl: 0.832               4: 0.693
# 6       samsung (samsung)           galaxi: 0.593             iii: 0.447
# 7     motorola (motorola)             razr: 0.593           droid: 0.539
# 8   headphones (headphon)        earpollut: 0.853       microphon: 0.812
# 9         galaxy (galaxi)                s: 0.652             iii: 0.647
# 10          droid (droid)                x: 0.725          bionic: 0.690
# 11    ericsson (ericsson)             soni: 0.883       cybershot: 0.765
# 12      microsd (microsd)        microsdhc: 0.959         sandisk: 0.885
# 13            razr (razr)               v3: 0.685            purs: 0.617
# 14            case (case)            plaid: 0.476       blackpink: 0.468
# 15  protector (protector)           screen: 0.897         protect: 0.702
# 16      leather (leather)             espn: 0.535           carri: 0.522
# 17      charger (charger)             wall: 0.623          travel: 0.622
# 18      unlocked (unlock)              att: 0.550        titanium: 0.491
#
#                   3                 4                       5   \
# 0   candyshel: 0.829      plaid: 0.793           hurley: 0.735
# 1        gaga: 0.810      venom: 0.801          macbeth: 0.791
# 2     blueant: 0.789  bluetooth: 0.745        discoveri: 0.712
# 3    electron: 0.745     credit: 0.740               to: 0.708
# 4          4s: 0.663        3gs: 0.615            kapok: 0.572
# 5          4s: 0.660        3gs: 0.617            kapok: 0.588
# 6          ii: 0.443         lg: 0.435            sanyo: 0.410
# 7        purs: 0.508         v3: 0.508           photon: 0.471
# 8      earbud: 0.805     jammin: 0.785           marley: 0.780
# 9        note: 0.647       epic: 0.624           captiv: 0.597
# 10     photon: 0.682    android: 0.662            atrix: 0.656
# 11     xperia: 0.760        x10: 0.751          walkman: 0.731
# 12      class: 0.841      stick: 0.827            capac: 0.811
# 13   motorola: 0.593       krzr: 0.577           bionic: 0.529
# 14      casem: 0.461        for: 0.443         pinkwhit: 0.432
# 15    maximum: 0.672     packag: 0.623  invisibleshield: 0.589
# 16       lean: 0.511     jensen: 0.500            pouch: 0.491
# 17     vehicl: 0.591    recharg: 0.575            charg: 0.571
# 18          t: 0.491  cybershot: 0.474       nocontract: 0.469
#
#                     6                 7                8   \
# 0         venom: 0.701    tekkeon: 0.689      lean: 0.687
# 1   antibacteri: 0.786       ladi: 0.770    marley: 0.741
# 2           blu: 0.700    headset: 0.664       era: 0.660
# 3         emerg: 0.690    mycharg: 0.663      bank: 0.630
# 4          teal: 0.566      incas: 0.545    ifrogz: 0.534
# 5          teal: 0.564    tekkeon: 0.549    canopi: 0.545
# 6        indulg: 0.398      pebbl: 0.393     marbl: 0.389
# 7          krzr: 0.456     devour: 0.454      a855: 0.453
# 8          hous: 0.774      onear: 0.685      ozon: 0.660
# 9         marbl: 0.594    samsung: 0.593     nexus: 0.544
# 10         a855: 0.586       a957: 0.586        x2: 0.577
# 11        rapid: 0.590     wilson: 0.583    siemen: 0.556
# 12         sdhc: 0.797        pni: 0.791       2gb: 0.789
# 13     cellstik: 0.522      spark: 0.513    photon: 0.502
# 14   blackclear: 0.431     burton: 0.409   leather: 0.408
# 15       surfac: 0.588       zagg: 0.560  fullbodi: 0.554
# 16          tan: 0.489      model: 0.489    hipcas: 0.485
# 17        rapid: 0.565         dc: 0.550        ac: 0.546
# 18      walkman: 0.461  refurbish: 0.454    gophon: 0.421
#
#                      9                10
# 0       hardshel: 0.683      puma: 0.677
# 1        fabshel: 0.735      puma: 0.705
# 2        walkman: 0.652    stereo: 0.612
# 3   broadband2go: 0.625      medi: 0.618
# 4           ipod: 0.531    canopi: 0.526
# 5          incas: 0.532    burton: 0.531
# 6           epic: 0.388   graviti: 0.387
# 7          mb200: 0.450     atrix: 0.437
# 8             of: 0.650       lux: 0.649
# 9         indulg: 0.543     googl: 0.520
# 10        devour: 0.569  backflip: 0.559
# 11          r225: 0.549  clearvox: 0.536
# 12      kingston: 0.741       4gb: 0.741
# 13         atrix: 0.495     drive: 0.490
# 14         frost: 0.403   ballist: 0.399
# 15             v: 0.548   sphm850: 0.540
# 16   brightpoint: 0.484   startac: 0.482
# 17       mycharg: 0.519   startac: 0.511
# 18          skin: 0.420    commut: 0.415

# %% [markdown]
# #### Min Count = {10, 20}, Epochs = 25

# %%
run_exp(epochs = 25, minCount=10)
run_exp(epochs = 25, minCount=20)
# Out:
# + fasttext skipgram -input phone_titles.txt -output phone_title_model.e25.mc10 -epoch 25 -minCount 10
# Read 0M words
# Number of words:  354
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  239997 lr:  0.000000 avg.loss:  2.305708 ETA:   0h 0m 0s
# + fasttext nn phone_title_model.e25.mc10.bin
#                        0                 1                 2   \
# 0      fabshell (fabshel)       soft: 0.922      atrix: 0.914
# 1         hurley (hurley)     oakley: 0.970       appl: 0.935
# 2     bluetrek (bluetrek)    blueant: 0.981  bluetooth: 0.966
# 3         energi (energi)      energ: 0.991       port: 0.930
# 4            apple (appl)     oakley: 0.976       teal: 0.971
# 5          iphone (iphon)       appl: 0.928        lux: 0.914
# 6       samsung (samsung)     galaxi: 0.912          s: 0.879
# 7     motorola (motorola)         v3: 0.911    station: 0.824
# 8   headphones (headphon)     earbud: 0.981  microphon: 0.965
# 9         galaxy (galaxi)          s: 0.947        iii: 0.943
# 10          droid (droid)          x: 0.911     bionic: 0.902
# 11    ericsson (ericsson)       soni: 0.942     xperia: 0.935
# 12      microsd (microsd)  microsdhc: 0.998    sandisk: 0.981
# 13            razr (razr)         v3: 0.896   motorola: 0.820
# 14            case (case)      sleev: 0.895     commut: 0.842
# 15  protector (protector)     screen: 0.967    protect: 0.895
# 16      leather (leather)      brown: 0.893      small: 0.888
# 17      charger (charger)     vehicl: 0.915      innov: 0.907
# 18      unlocked (unlock)   titanium: 0.844      torch: 0.824
#
#                     3                 4                  5               6   \
# 0         shell: 0.910      shift: 0.909     ballist: 0.897   fascin: 0.889
# 1             4: 0.934    macbeth: 0.929      reveal: 0.928       4s: 0.922
# 2   bluetoothen: 0.956   plantron: 0.932     headset: 0.921   explor: 0.896
# 3          dual: 0.924      power: 0.913       devic: 0.899  portabl: 0.875
# 4     lifeproof: 0.957      incas: 0.952      slider: 0.948        4: 0.945
# 5             4: 0.903       teal: 0.897      ifrogz: 0.891   oakley: 0.888
# 6       vibrant: 0.854         ii: 0.852      captiv: 0.843     note: 0.836
# 7          razr: 0.820      droid: 0.806           x: 0.791   photon: 0.781
# 8          ozon: 0.941     ifrogz: 0.938         lux: 0.931       of: 0.914
# 9            ii: 0.926     captiv: 0.915     samsung: 0.912     note: 0.876
# 10       photon: 0.897      atrix: 0.875           2: 0.867   incred: 0.863
# 11        liion: 0.835   audiovox: 0.818  lithiumion: 0.802    nokia: 0.785
# 12        capac: 0.973        pni: 0.972         4gb: 0.968      1gb: 0.966
# 13       swivel: 0.759      ultra: 0.732      bionic: 0.731  compani: 0.731
# 14      ballist: 0.836    silicon: 0.833       shell: 0.831  macbeth: 0.823
# 15         zagg: 0.883  softtouch: 0.877           x: 0.860   fascin: 0.860
# 16        pouch: 0.868     milant: 0.855         esi: 0.851      rim: 0.850
# 17         wall: 0.905     travel: 0.879    cellular: 0.801  desktop: 0.799
# 18        storm: 0.823       9800: 0.816       pearl: 0.806     dark: 0.803
#
#                         7                  8                  9   \
# 0         softtouch: 0.887         gel: 0.884  rocketfish: 0.883
# 1              teal: 0.917       metal: 0.912       speck: 0.907
# 2             jabra: 0.885      jawbon: 0.884       prime: 0.883
# 3               igo: 0.875      system: 0.868       charg: 0.858
# 4           macbeth: 0.941       speck: 0.931       iphon: 0.928
# 5                4s: 0.886   lifeproof: 0.883       incas: 0.883
# 6              epic: 0.828  multimedia: 0.816         iii: 0.814
# 7            vehicl: 0.777      bionic: 0.773     desktop: 0.769
# 8             iphon: 0.791        with: 0.788         bud: 0.787
# 9              epic: 0.868     vibrant: 0.842       nexus: 0.840
# 10          station: 0.850      fascin: 0.841       shift: 0.836
# 11           jensen: 0.763      select: 0.758      lenmar: 0.756
# 12            class: 0.963        high: 0.957         8gb: 0.932
# 13            sanyo: 0.722    cellsuit: 0.721        clip: 0.709
# 14           defend: 0.823      impact: 0.820        snap: 0.814
# 15  invisibleshield: 0.852       shift: 0.851       clear: 0.842
# 16             flip: 0.847      vertic: 0.841      jensen: 0.838
# 17            charg: 0.799          ac: 0.787        dual: 0.780
# 18             9000: 0.796    sidekick: 0.785  blackberri: 0.779
#
#                   10
# 0        6300: 0.882
# 1   lifeproof: 0.905
# 2         bud: 0.881
# 3      extern: 0.856
# 4          4s: 0.921
# 5         3gs: 0.875
# 6       mount: 0.812
# 7      xperia: 0.759
# 8       micro: 0.774
# 9     graviti: 0.813
# 10         4g: 0.827
# 11    batteri: 0.751
# 12         10: 0.918
# 13   cliphang: 0.709
# 14   otterbox: 0.812
# 15       epic: 0.825
# 16    essenti: 0.836
# 17     jensen: 0.779
# 18  blackjack: 0.774
# + fasttext skipgram -input phone_titles.txt -output phone_title_model.e25.mc20 -epoch 25 -minCount 20
# Read 0M words
# Number of words:  211
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  319895 lr:  0.000000 avg.loss:  2.529816 ETA:   0h 0m 0s
# + fasttext nn phone_title_model.e25.mc20.bin
#                        0                 1                   2   \
# 0      fabshell (fabshel)        gel: 0.945        shell: 0.942
# 1         hurley (hurley)        car: 0.146     handsfre: 0.139
# 2     bluetrek (bluetrek)  bluetooth: 0.966  bluetoothen: 0.958
# 3         energi (energi)     virgin: 0.989           50: 0.974
# 4            apple (appl)      incas: 0.964            4: 0.963
# 5          iphone (iphon)        lux: 0.929        speck: 0.921
# 6       samsung (samsung)      mount: 0.892       galaxi: 0.891
# 7     motorola (motorola)       razr: 0.872        mount: 0.837
# 8   headphones (headphon)     earbud: 0.989    microphon: 0.953
# 9         galaxy (galaxi)        iii: 0.969            s: 0.961
# 10          droid (droid)     incred: 0.948            x: 0.929
# 11    ericsson (ericsson)       soni: 0.962     audiovox: 0.930
# 12      microsd (microsd)  microsdhc: 0.997      sandisk: 0.984
# 13            razr (razr)   motorola: 0.872         clip: 0.790
# 14            case (case)      sleev: 0.934         snap: 0.910
# 15  protector (protector)     screen: 0.988            x: 0.907
# 16      leather (leather)      small: 0.948          rim: 0.942
# 17      charger (charger)       wall: 0.929       vehicl: 0.924
# 18      unlocked (unlock)       gray: 0.892         dark: 0.853
#
#                  3                  4               5                 6   \
# 0   communic: 0.917     silicon: 0.906   incred: 0.900     commut: 0.900
# 1       mini: 0.137       micro: 0.137    jabra: 0.137   plantron: 0.131
# 2   plantron: 0.953     headset: 0.947   silver: 0.920      jabra: 0.915
# 3     airtim: 0.970       topup: 0.966  prepaid: 0.961         20: 0.955
# 4     slider: 0.962          4s: 0.962      3gs: 0.956      speck: 0.948
# 5     ifrogz: 0.916        appl: 0.915        4: 0.910      incas: 0.903
# 6         ii: 0.887        dock: 0.847    nexus: 0.845          s: 0.845
# 7    desktop: 0.831      nextel: 0.826    sanyo: 0.810      innov: 0.808
# 8     ifrogz: 0.919         lux: 0.875    iphon: 0.849   plantron: 0.801
# 9         ii: 0.939          4g: 0.917  samsung: 0.891      nexus: 0.881
# 10    xentri: 0.921         evo: 0.907  holster: 0.897        one: 0.894
# 11   kyocera: 0.920       nokia: 0.918   select: 0.907       most: 0.906
# 12     class: 0.970         8gb: 0.933   memori: 0.925      micro: 0.921
# 13   compani: 0.786     holster: 0.782        2: 0.781      droid: 0.773
# 14   silicon: 0.906        pink: 0.897    shell: 0.888  blackwhit: 0.887
# 15    packag: 0.902     protect: 0.890     zagg: 0.872       wall: 0.862
# 16  cellstar: 0.928    cellsuit: 0.909     init: 0.905     jensen: 0.902
# 17     innov: 0.883      travel: 0.874   nextel: 0.834      charg: 0.787
# 18     pearl: 0.850  blackberri: 0.841   sprint: 0.840        red: 0.823
#
#                 7                 8                   9                   10
# 0     sleev: 0.900       pink: 0.893         case: 0.893     superior: 0.891
# 1       igo: 0.131      adapt: 0.130      headset: 0.128  speakerphon: 0.125
# 2    jawbon: 0.915  blacksilv: 0.914  speakerphon: 0.912         jack: 0.909
# 3   cricket: 0.955      net10: 0.947         card: 0.902   nocontract: 0.902
# 4   griffin: 0.942        dlo: 0.924        iphon: 0.915           3g: 0.910
# 5       3gs: 0.901         4s: 0.894       slider: 0.891          fit: 0.868
# 6   pantech: 0.837         lg: 0.829          iii: 0.807      desktop: 0.796
# 7      dock: 0.807     jensen: 0.804       travel: 0.804         just: 0.799
# 8      with: 0.800     jawbon: 0.793  speakerphon: 0.792        micro: 0.788
# 9    sprint: 0.846    pantech: 0.839         epic: 0.830      graviti: 0.807
# 10   snapon: 0.883          2: 0.880           hd: 0.878           3d: 0.862
# 11       hp: 0.893     lenmar: 0.885         pdas: 0.878       signal: 0.872
# 12     16gb: 0.885       card: 0.874    microphon: 0.854    refurbish: 0.851
# 13    mount: 0.763         hd: 0.762          the: 0.754          one: 0.752
# 14      dlo: 0.886     defend: 0.870        incas: 0.859        2pack: 0.857
# 15    clear: 0.854         by: 0.854         epic: 0.847        cover: 0.841
# 16    glove: 0.902       bodi: 0.900         treo: 0.897    smartphon: 0.895
# 17      car: 0.778       just: 0.774       packag: 0.774     cellular: 0.768
# 18    black: 0.821       bold: 0.819      metropc: 0.817         8530: 0.815
